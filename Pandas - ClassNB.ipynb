# %% [markdown]
# # Introduction to Pandas for data manupulation
# ### Pandas is an open-source python library that is used for data manipulation and analysis.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What is Pandas?
# * Pandas is a Python library used for working with data sets.
# * It has functions for analyzing, cleaning, exploring, and manipulating data.
# * The name "Pandas" has a reference to both "Panel Data", and "Python Data Analysis" and was created by Wes McKinney in 2008.

# %% [markdown]
# ## Why Use Pandas?
# * Pandas allows us to analyze big data and make conclusions based on statistical theories.
# * Pandas can clean messy data sets, and make them readable and relevant.
# * Relevant data is very important in data science.
# * https://pandas.pydata.org/pandas-docs/stable/reference/

# %% [markdown]
# ## A Pandas DataFrame is a 2 dimensional data structure, like a 2 dimensional array, or a table with rows and columns.

# %%
import pandas as pd # pip install pandas
 #Query to get additional information

# %%
import numpy as np
np?

# %% [markdown]
# ### Create a DataFrame from list

# %%
data=[['Sia',21],['Nick',20],['James',19]]
type(data)
# Out:
# list

# %%
print(data)
# Out:
# [['Sia', 21], ['Nick', 20], ['James', 19]]

# %%
df_list=pd.DataFrame(data,columns=['Name','Age'])
print(df_list)
# Out:
#     Name  Age
# 0    Sia   21
# 1   Nick   20
# 2  James   19

# %%
type(df_list)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Create a DataFrame from NumPy array

# %%
data1=np.array([['Sia',21],['Nick',20],['James',19]])
type(data1)
# Out:
# numpy.ndarray

# %%
df_array=pd.DataFrame(data1,columns=['Name','Age'])
df_array
# Out:
#     Name Age
# 0    Sia  21
# 1   Nick  20
# 2  James  19

# %% [markdown]
# ### Create a DataFrame from dictionary

# %%
data2={'Name': ['Sia','Nick','James'], 'Age': [21,20,19]}
data2
# Out:
# {'Name': ['Sia', 'Nick', 'James'], 'Age': [21, 20, 19]}

# %%
type(data2)
# Out:
# dict

# %%
df_dict=pd.DataFrame(data2)
df_dict
# Out:
#     Name  Age
# 0    Sia   21
# 1   Nick   20
# 2  James   19

# %% [markdown]
# ## Read
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html

# %%
df=pd.read_csv("police.csv")

# %% [markdown]
# ### head() to display the top 5 rows from our data set.
# ### tail() to display last 5 rows

# %%
df.head()
# Out:
#    stop_date stop_time  county_name driver_gender  driver_age_raw  driver_age  \
# 0   9/8/2013      9:50          NaN             F            1914        99.0
# 1   9/6/2006     12:15          NaN             M            1918        88.0
# 2  2/14/2014     10:21          NaN             M            1920        94.0
# 3   2/4/2008     14:40          NaN             M            1922        86.0
# 4  2/15/2008     14:34          NaN             M            1922        86.0
#
#   driver_race            violation_raw         violation  search_conducted  \
# 0       White  Other Traffic Violation  Moving violation             False
# 1       White                 Speeding          Speeding             False
# 2       White  Other Traffic Violation  Moving violation             False
# 3       White                 Speeding          Speeding             False
# 4       White                 Speeding          Speeding             False
#
#   stop_outcome is_arrested  drugs_related_stop
# 0     Citation       False               False
# 1     Citation       False               False
# 2     Citation       False               False
# 3     Citation       False               False
# 4     Citation       False               False

# %%
#top 10 values
df.head(10)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0    9/8/2013      9:50          NaN             F            1914
# 1    9/6/2006     12:15          NaN             M            1918
# 2   2/14/2014     10:21          NaN             M            1920
# 3    2/4/2008     14:40          NaN             M            1922
# 4   2/15/2008     14:34          NaN             M            1922
# 5    4/5/2008     10:07          NaN             M            1922
# 6  11/10/2005     18:58          NaN             M            1923
# 7  11/17/2009     15:33          NaN             M            1923
# 8   6/20/2011     12:05          NaN             M            1923
# 9  10/28/2005      9:40          NaN             M            1924
#
#    driver_age driver_race            violation_raw         violation  \
# 0        99.0       White  Other Traffic Violation  Moving violation
# 1        88.0       White                 Speeding          Speeding
# 2        94.0       White  Other Traffic Violation  Moving violation
# 3        86.0       White                 Speeding          Speeding
# 4        86.0       White                 Speeding          Speeding
# 5        86.0       White                 Speeding          Speeding
# 6        82.0       White                 Speeding          Speeding
# 7        86.0       White  Other Traffic Violation  Moving violation
# 8        88.0       White                 Speeding          Speeding
# 9        81.0       White                 Speeding          Speeding
#
#    search_conducted stop_outcome is_arrested  drugs_related_stop
# 0             False     Citation       False               False
# 1             False     Citation       False               False
# 2             False     Citation       False               False
# 3             False     Citation       False               False
# 4             False     Citation       False               False
# 5             False     Citation       False               False
# 6             False     Citation       False               False
# 7             False     Citation       False               False
# 8             False      Warning       False               False
# 9             False     Citation       False               False

# %%
df.tail(5)
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 86149  11/12/2008      7:04          NaN             M            2008
# 86150   10/7/2009     21:15          NaN             M            2009
# 86151   3/26/2012     12:50          NaN             M            2009
# 86152    2/5/2012     13:54          NaN             M            2011
# 86153    2/4/2013      8:31          NaN             M            2013
#
#        driver_age driver_race                   violation_raw  \
# 86149         NaN       White                        Speeding
# 86150         NaN    Hispanic                        Speeding
# 86151         NaN       White        Motorist Assist/Courtesy
# 86152         NaN       White  Special Detail/Directed Patrol
# 86153         NaN       White          Registration Violation
#
#                  violation  search_conducted stop_outcome is_arrested  \
# 86149             Speeding             False     Citation       False
# 86150             Speeding             False     Citation       False
# 86151                Other             False    No Action       False
# 86152                Other             False     Citation       False
# 86153  Registration/plates              True     Citation       False
#
#        drugs_related_stop
# 86149               False
# 86150               False
# 86151               False
# 86152               False
# 86153                True

# %% [markdown]
# ### `sample()` allows us to choose random values from our data frame. We can pass it the no. of rows that we want to fetch as a parameter

# %%
df.sample(5)
# Out:
#        stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 27289  2/13/2009      6:45          NaN             M            1971
# 78834  7/11/2013      1:42          NaN             M            1991
# 54045  5/22/2006     12:00          NaN             M            1984
# 36756   8/8/2006     17:15          NaN             M            1977
# 9938   8/31/2013     13:06          NaN             M            1958
#
#        driver_age driver_race                   violation_raw  violation  \
# 27289        38.0       Black  Special Detail/Directed Patrol      Other
# 78834        22.0       White  Equipment/Inspection Violation  Equipment
# 54045        22.0       White                        Speeding   Speeding
# 36756        29.0       White                        Speeding   Speeding
# 9938         55.0       White                        Speeding   Speeding
#
#        search_conducted stop_outcome is_arrested  drugs_related_stop
# 27289             False     Citation       False               False
# 78834             False     Citation       False               False
# 54045             False     Citation       False               False
# 36756             False     Citation       False               False
# 9938              False     Citation       False               False

# %% [markdown]
# ## `shape` to see dimension of our dataset,

# %%
df.shape
#rows, columns
# Out:
# (86154, 13)

# %% [markdown]
# ### More information about dataset
# - info()
# - columns: get the name of all the features/columns in our data frame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86154 entries, 0 to 86153
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           86154 non-null  object
#  1   stop_time           86154 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86147 non-null  object
#  4   driver_age_raw      86154 non-null  int64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86149 non-null  object
#  7   violation_raw       86149 non-null  object
#  8   violation           86149 non-null  object
#  9   search_conducted    86154 non-null  bool
#  10  stop_outcome        86149 non-null  object
#  11  is_arrested         86149 non-null  object
#  12  drugs_related_stop  86154 non-null  bool
# dtypes: bool(2), float64(2), int64(1), object(8)
# memory usage: 7.4+ MB

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'stop_outcome', 'is_arrested',
#        'drugs_related_stop'],
#       dtype='object')

# %% [markdown]
# ### datetime()
# Pandas to_datetime() is able to parse any valid date string to datetime without any additional arguments.
# * Convert strings to datetime
# * Assemble a datetime from multiple columns
# * Get year, month and day
# * Get the week of year, the day of week, and leap year
# * Get the age from the date of birth
# * Improve performance by setting date column as the index
# * Select data with a specific year and perform aggregation
# * Select data with a specific month and a specific day of the month
# * Select data between two dates
# * Handle missing values
# ### Try all those:
# 1. print(pd.datetime.now())
# 2. print(pd.datetime.now().date())
# 3. print(pd.datetime.now().year)
# 4. print(pd.datetime.now().month)
# 5. print(pd.datetime.now().day)
# 6. print(pd.datetime.now().hour)
# 7. print(pd.datetime.now().minute)
# 8. print(pd.datetime.now().second)
# 9. print(pd.datetime.now().microsecond)

# %%
from datetime import datetime
datetime.now()
# Out:
# datetime.datetime(2023, 9, 14, 10, 11, 4, 913773)

# %%
datetime.now().minute
# Out:
# 11

# %%
datetime.now().hour
# Out:
# 10

# %%
datetime.now().year
# Out:
# 2023

# %%
df['stop_date']=pd.to_datetime(df['stop_date'])

# %%
df['stop_time']=pd.to_datetime(df['stop_time'])
# Out:
# C:\Users\rhukom\AppData\Local\Temp\ipykernel_920\844405240.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['stop_time']=pd.to_datetime(df['stop_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86154 entries, 0 to 86153
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           86154 non-null  datetime64[ns]
#  1   stop_time           86154 non-null  datetime64[ns]
#  2   county_name         0 non-null      float64
#  3   driver_gender       86147 non-null  object
#  4   driver_age_raw      86154 non-null  int64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86149 non-null  object
#  7   violation_raw       86149 non-null  object
#  8   violation           86149 non-null  object
#  9   search_conducted    86154 non-null  bool
#  10  stop_outcome        86149 non-null  object
#  11  is_arrested         86149 non-null  object
#  12  drugs_related_stop  86154 non-null  bool
# dtypes: bool(2), datetime64[ns](2), float64(2), int64(1), object(6)
# memory usage: 7.4+ MB

# %%
df.head()
# Out:
#    stop_date           stop_time  county_name driver_gender  driver_age_raw  \
# 0 2013-09-08 2023-09-14 09:50:00          NaN             F            1914
# 1 2006-09-06 2023-09-14 12:15:00          NaN             M            1918
# 2 2014-02-14 2023-09-14 10:21:00          NaN             M            1920
# 3 2008-02-04 2023-09-14 14:40:00          NaN             M            1922
# 4 2008-02-15 2023-09-14 14:34:00          NaN             M            1922
#
#    driver_age driver_race            violation_raw         violation  \
# 0        99.0       White  Other Traffic Violation  Moving violation
# 1        88.0       White                 Speeding          Speeding
# 2        94.0       White  Other Traffic Violation  Moving violation
# 3        86.0       White                 Speeding          Speeding
# 4        86.0       White                 Speeding          Speeding
#
#    search_conducted stop_outcome is_arrested  drugs_related_stop
# 0             False     Citation       False               False
# 1             False     Citation       False               False
# 2             False     Citation       False               False
# 3             False     Citation       False               False
# 4             False     Citation       False               False

# %%
df['year'] = df['stop_date'].dt.year

# %%
df['month']=df['stop_date'].dt.month
df['day']=df['stop_date'].dt.day

# %%
df.head()
# Out:
#    stop_date           stop_time  county_name driver_gender  driver_age_raw  \
# 0 2013-09-08 2023-09-14 09:50:00          NaN             F            1914
# 1 2006-09-06 2023-09-14 12:15:00          NaN             M            1918
# 2 2014-02-14 2023-09-14 10:21:00          NaN             M            1920
# 3 2008-02-04 2023-09-14 14:40:00          NaN             M            1922
# 4 2008-02-15 2023-09-14 14:34:00          NaN             M            1922
#
#    driver_age driver_race            violation_raw         violation  \
# 0        99.0       White  Other Traffic Violation  Moving violation
# 1        88.0       White                 Speeding          Speeding
# 2        94.0       White  Other Traffic Violation  Moving violation
# 3        86.0       White                 Speeding          Speeding
# 4        86.0       White                 Speeding          Speeding
#
#    search_conducted stop_outcome is_arrested  drugs_related_stop  year  month  \
# 0             False     Citation       False               False  2013      9
# 1             False     Citation       False               False  2006      9
# 2             False     Citation       False               False  2014      2
# 3             False     Citation       False               False  2008      2
# 4             False     Citation       False               False  2008      2
#
#    day
# 0    8
# 1    6
# 2   14
# 3    4
# 4   15

# %%
df['hour']=df['stop_time'].dt.hour
df.sample(3)
# Out:
#        stop_date           stop_time  county_name driver_gender  \
# 62316 2011-06-25 2023-09-14 08:42:00          NaN             M
# 34083 2011-12-17 2023-09-14 16:50:00          NaN             F
# 79990 2011-02-25 2023-09-14 16:04:00          NaN             M
#
#        driver_age_raw  driver_age driver_race  \
# 62316            1986        25.0       Black
# 34083            1975        36.0       White
# 79990            1992        19.0       White
#
#                           violation_raw violation  search_conducted  \
# 62316                          Speeding  Speeding             False
# 34083  Violation of City/Town Ordinance     Other             False
# 79990  Violation of City/Town Ordinance     Other             False
#
#       stop_outcome is_arrested  drugs_related_stop  year  month  day  hour
# 62316     Citation       False               False  2011      6   25     8
# 34083     Citation       False               False  2011     12   17    16
# 79990     Citation       False               False  2011      2   25    16

# %%
df['driver_age'] = 2023 - df['driver_age_raw']
df.sample(3)
# Out:
#        stop_date           stop_time  county_name driver_gender  \
# 82463 2013-07-05 2023-09-14 13:47:00          NaN             M
# 36037 2013-01-22 2023-09-14 22:36:00          NaN             M
# 46024 2008-01-13 2023-09-14 14:30:00          NaN             F
#
#        driver_age_raw  driver_age driver_race                   violation_raw  \
# 82463            1993          30    Hispanic  Equipment/Inspection Violation
# 36037            1976          47       White         Other Traffic Violation
# 46024            1981          42       White                        Speeding
#
#               violation  search_conducted stop_outcome is_arrested  \
# 82463         Equipment             False      Warning       False
# 36037  Moving violation             False     Citation       False
# 46024          Speeding             False     Citation       False
#
#        drugs_related_stop  year  month  day  hour
# 82463               False  2013      7    5    13
# 36037               False  2013      1   22    22
# 46024               False  2008      1   13    14

# %% [markdown]
# ###  `drop()` to drop that particular column
# - The `axis` argument specifies whether to drop rows (0) or columns (1).
# - The `inplace` argument specifies to drop the columns in place without reassigning the DataFrame.

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'county_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'stop_outcome', 'is_arrested',
#        'drugs_related_stop', 'year', 'month', 'day', 'hour'],
#       dtype='object')

# %%
df.drop(['county_name','driver_age_raw','violation_raw','month','day','hour'],axis=1,inplace=True) #axis 1 columns, 0 rows. 
df.sample(3)
# Out:
#        stop_date           stop_time driver_gender  driver_age driver_race  \
# 35493 2009-11-14 2023-09-14 07:50:00             M          47       White
# 55956 2012-08-08 2023-09-14 23:13:00             M          39       Black
# 51124 2006-09-19 2023-09-14 23:05:00             M          40       White
#
#               violation  search_conducted stop_outcome is_arrested  \
# 35493  Moving violation             False     Citation       False
# 55956          Speeding             False     Citation       False
# 51124         Equipment             False     Citation       False
#
#        drugs_related_stop  year
# 35493               False  2009
# 55956               False  2012
# 51124               False  2006

# %% [markdown]
# ### `nunique()`  can use to find the no. of unique values in our series or data

# %%
df['violation'].nunique()
# Out:
# 6

# %%
df['driver_race'].nunique()
# Out:
# 5

# %% [markdown]
# ### value_counts() is used to identify the different categories in a feature as well as the count of values per category

# %%
df['violation'].value_counts()
# Out:
# violation
# Speeding               48384
# Moving violation       16170
# Equipment              11008
# Other                   4207
# Registration/plates     3428
# Seat belt               2952
# Name: count, dtype: int64

# %%
df['search_conducted'].value_counts()
# Out:
# search_conducted
# False    82959
# True      3195
# Name: count, dtype: int64

# %%
#driver_race
df['driver_race'].value_counts()
# Out:
# driver_race
# White       61972
# Black       12203
# Hispanic     9482
# Asian        2253
# Other         239
# Name: count, dtype: int64

# %%
#stop_outcome 
df['stop_outcome'].value_counts()
# Out:
# stop_outcome
# Citation            76851
# Warning              5216
# Arrest Driver        2569
# N/D                   590
# No Action             565
# Arrest Passenger      358
# Name: count, dtype: int64

# %% [markdown]
# ### `describe()`to get various information about the numerical columns

# %%
df.describe()
# Out:
#                            stop_date                      stop_time  \
# count                          86154                          86154
# mean   2010-10-09 17:14:47.777700096  2023-09-14 12:09:30.869838080
# min              2005-01-02 00:00:00            2023-09-14 00:00:00
# 25%              2008-01-02 00:00:00            2023-09-14 08:14:00
# 50%              2010-11-19 00:00:00            2023-09-14 11:40:00
# 75%              2013-05-23 00:00:00            2023-09-14 16:34:00
# max              2015-12-31 00:00:00            2023-09-14 23:59:00
# std                              NaN                            NaN
#
#          driver_age          year
# count  86154.000000  86154.000000
# mean      46.720059   2010.278884
# min       10.000000   2005.000000
# 25%       36.000000   2008.000000
# 50%       43.000000   2010.000000
# 75%       56.000000   2013.000000
# max      109.000000   2015.000000
# std       13.073356      3.046527

# %% [markdown]
# ### `isnull()`.sum() to find that the no. of null values in a DataFrame

# %%
df.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# driver_gender         7
# driver_age            0
# driver_race           5
# violation             5
# search_conducted      0
# stop_outcome          5
# is_arrested           5
# drugs_related_stop    0
# year                  0
# dtype: int64

# %% [markdown]
# ###  `fillna()` by using the “isnull()” and “sum()” functions, we can check if our data has any missing values or not. we will fill up the missing values using the mode(a value that appears most frequently in a data set) of this particular feature using the “fillna()” function.
# - mean (Numerical)
# - mode/most frequent (Numerical/ Categorical)
# - median (Numerical)
# - constant(Numerical/ categorical)

# %% [markdown]
# #### inplace=true
# * Pandas create a copy of the original data.
# * Performs the required operation on it.
# * Assigns the results to the original data. (Important point to consider here).
# * Then deletes the copy.

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'driver_gender', 'driver_age', 'driver_race',
#        'violation', 'search_conducted', 'stop_outcome', 'is_arrested',
#        'drugs_related_stop', 'year'],
#       dtype='object')

# %%
gender=df['driver_gender'].mode()[0]
print(gender)
df['driver_gender'].fillna(gender,inplace=True)
df['driver_gender'].isnull().sum()
# Out:
# M
# 0

# %%
#driver_race
race=df['driver_race'].mode()[0]
print(race)
df['driver_race'].fillna(race,inplace=True)
df['driver_race'].isnull().sum()
# Out:
# White
# 0

# %%
#stop_outcome
stop_outcome=df['stop_outcome'].mode()[0]
print(stop_outcome)
df['stop_outcome'].fillna('Unknown',inplace=True)
df['stop_outcome'].isnull().sum()
# Out:
# Citation
# 0

# %%
#is_arrested
is_arrested=df['is_arrested'].mode()[0]
print(is_arrested)
df['is_arrested'].fillna(is_arrested,inplace=True)
df['is_arrested'].isnull().sum()
# Out:
# False
# 0

# %%
#violation
violation=df['violation'].mode()[0]
print(violation)
df['violation'].fillna(violation,inplace=True)
df['violation'].isnull().sum()
# Out:
# Speeding
# 0

# %% [markdown]
# ### Plot Make plots of Series or DataFrame.
#
# Uses the backend specified by the option plotting.backend. By default, matplotlib is used. The `kind` of plot to produce:
#
# - ‘line’ : line plot (default)
#
# - ‘bar’ : vertical bar plot
#
# - ‘barh’ : horizontal bar plot
#
# - ‘hist’ : histogram
#
# - ‘box’ : boxplot
#
# - ‘kde’ : Kernel Density Estimation plot
#
# - ‘density’ : same as ‘kde’
#
# - ‘area’ : area plot
#
# - ‘pie’ : pie plot
#
# - ‘scatter’ : scatter plot (DataFrame only)
#
# - ‘hexbin’ : hexbin plot (DataFrame only)

# %%
df.columns
# Out:
# Index(['stop_date', 'stop_time', 'driver_gender', 'driver_age', 'driver_race',
#        'violation', 'search_conducted', 'stop_outcome', 'is_arrested',
#        'drugs_related_stop', 'year'],
#       dtype='object')

# %%
#bar plot for violation
df['violation'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='violation'>

# %%
#pie plot for violation
df['violation'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#histogram for age
df['driver_age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#boxplot for age
df['driver_age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#                            stop_date                      stop_time  \
# count                          86154                          86154
# mean   2010-10-09 17:14:47.777700096  2023-09-14 12:09:30.869838080
# min              2005-01-02 00:00:00            2023-09-14 00:00:00
# 25%              2008-01-02 00:00:00            2023-09-14 08:14:00
# 50%              2010-11-19 00:00:00            2023-09-14 11:40:00
# 75%              2013-05-23 00:00:00            2023-09-14 16:34:00
# max              2015-12-31 00:00:00            2023-09-14 23:59:00
# std                              NaN                            NaN
#
#          driver_age          year
# count  86154.000000  86154.000000
# mean      46.720059   2010.278884
# min       10.000000   2005.000000
# 25%       36.000000   2008.000000
# 50%       43.000000   2010.000000
# 75%       56.000000   2013.000000
# max      109.000000   2015.000000
# std       13.073356      3.046527

# %%
#Plot horiz bar for stop_outcome
df['stop_outcome'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='stop_outcome'>

# %%
df.plot.scatter(x='year',y='driver_age')
# Out:
# <Axes: xlabel='year', ylabel='driver_age'>

# %% [markdown]
# ###  `nsmallest() & nlargest()` used to obtain “n” no. of rows from our dataset which are lowest or highest respectively

# %%
df.nlargest(3, 'driver_age')
# Out:
#    stop_date           stop_time driver_gender  driver_age driver_race  \
# 0 2013-09-08 2023-09-14 09:50:00             F         109       White
# 1 2006-09-06 2023-09-14 12:15:00             M         105       White
# 2 2014-02-14 2023-09-14 10:21:00             M         103       White
#
#           violation  search_conducted stop_outcome  is_arrested  \
# 0  Moving violation             False     Citation        False
# 1          Speeding             False     Citation        False
# 2  Moving violation             False     Citation        False
#
#    drugs_related_stop  year
# 0               False  2013
# 1               False  2006
# 2               False  2014

# %%
df.nsmallest(3, 'driver_age')
# Out:
#        stop_date           stop_time driver_gender  driver_age driver_race  \
# 86153 2013-02-04 2023-09-14 08:31:00             M          10       White
# 86152 2012-02-05 2023-09-14 13:54:00             M          12       White
# 86150 2009-10-07 2023-09-14 21:15:00             M          14    Hispanic
#
#                  violation  search_conducted stop_outcome  is_arrested  \
# 86153  Registration/plates              True     Citation        False
# 86152                Other             False     Citation        False
# 86150             Speeding             False     Citation        False
#
#        drugs_related_stop  year
# 86153                True  2013
# 86152               False  2012
# 86150               False  2009

# %% [markdown]
# ### `groupby()` is very useful in data analysis as it allows us to unveil the underlying relationships among different variables.
# And then we can apply Aggregations as well on the groups with the “agg()” function and pass it with various aggregation operations such as mean, size, sum, std etc.

# %%
import numpy as np
df.groupby('driver_race').median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\groupby.py:1870, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1869 try:
# -> 1870     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1871 except Exception as err:
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\groupby.py:2456, in GroupBy.median.<locals>.<lambda>(x)
#    2383 """
#    2384 Compute median of groups, excluding missing values.
#    2385
#    (...)
#    2452 Freq: MS, dtype: float64
#    2453 """
#    2454 result = self._cython_agg_general(
#    2455     "median",
# -> 2456     alt=lambda x: Series(x).median(numeric_only=numeric_only),
#    2457     numeric_only=numeric_only,
#    2458 )
#    2459 return result.__finalize__(self.obj, method="groupby")
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\series.py:6236, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6228 @doc(make_doc("median", ndim=1))
#    6229 def median(
#    6230     self,
#    (...)
#    6234     **kwargs,
#    6235 ):
# -> 6236     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\generic.py:11980, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11973 def median(
#   11974     self,
#   11975     axis: Axis | None = 0,
#    (...)
#   11978     **kwargs,
#   11979 ) -> Series | float:
# > 11980     return self._stat_function(
#   11981         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11982     )
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\generic.py:11926, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11924 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11926 return self._reduce(
#   11927     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11928 )
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\series.py:6134, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6130     raise TypeError(
#    6131         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6132         "with non-numeric dtypes."
#    6133     )
# -> 6134 return op(delegate, skipna=skipna, **kwds)
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\nanops.py:783, in nanmedian(values, axis, skipna, mask)
#     782     if inferred in ["string", "mixed"]:
# --> 783         raise TypeError(f"Cannot convert {values} to numeric")
#     784 try:
#
# TypeError: Cannot convert ['M' 'M' 'M' ... 'F' 'M' 'F'] to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 import numpy as np
# ----> 2 df.groupby('driver_race').median()
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.median(self, numeric_only)
#    2381 @final
#    2382 def median(self, numeric_only: bool = False):
#    2383     """
#    2384     Compute median of groups, excluding missing values.
#    2385
#    (...)
#    2452     Freq: MS, dtype: float64
#    2453     """
# -> 2454     result = self._cython_agg_general(
#    2455         "median",
#    2456         alt=lambda x: Series(x).median(numeric_only=numeric_only),
#    2457         numeric_only=numeric_only,
#    2458     )
#    2459     return result.__finalize__(self.obj, method="groupby")
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\groupby.py:1925, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1922     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1923     return result
# -> 1925 new_mgr = data.grouped_reduce(array_func)
#    1926 res = self._wrap_agged_manager(new_mgr)
#    1927 out = self._wrap_aggregated_output(res)
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\internals\managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\internals\blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\groupby.py:1922, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1919 else:
#    1920     return result
# -> 1922 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1923 return result
#
# File ~\.conda\envs\DS160\lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1872     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1873     # preserve the kind of exception that raised
# -> 1874     raise type(err)(msg) from err
#    1876 if ser.dtype == object:
#    1877     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->median,dtype->object]

# %%
df.groupby('violation').mean()

# %% [markdown]
# ### loc() and iloc()
# loc() and iloc() methods are used in slicing data from the pandas DataFrame which helps in filtering the data according to some given condition.
# * loc – select by labels
# * iloc – select by positions

# %%
# Location of driver_age and violation
df.loc[:,['driver_age','violation']]
# Out:
#        driver_age            violation
# 0             109     Moving violation
# 1             105             Speeding
# 2             103     Moving violation
# 3             101             Speeding
# 4             101             Speeding
# ...           ...                  ...
# 86149          15             Speeding
# 86150          14             Speeding
# 86151          14                Other
# 86152          12                Other
# 86153          10  Registration/plates
#
# [86154 rows x 2 columns]

# %%
# Location of driver_age and violation for rows 3 to 10
df.loc[3:10,['driver_age','violation']]
# Out:
#     driver_age         violation
# 3          101          Speeding
# 4          101          Speeding
# 5          101          Speeding
# 6          100          Speeding
# 7          100  Moving violation
# 8          100          Speeding
# 9           99          Speeding
# 10          99          Speeding

# %%
# Location of driver_age and violation for rows 3 to 10 step of 2
df.loc[3:10:2,['driver_age','violation']]
# Out:
#    driver_age         violation
# 3         101          Speeding
# 5         101          Speeding
# 7         100  Moving violation
# 9          99          Speeding

# %%
#print the entries where the driver age is less than 17 and the violation is 
df.loc[(df.driver_age<17) & (df.violation=='Speeding')].sample(3)
# Out:
#        stop_date           stop_time driver_gender  driver_age driver_race  \
# 86146 2008-05-29 2023-09-14 16:50:00             M          16       White
# 86148 2008-09-11 2023-09-14 11:15:00             M          15       Black
# 86143 2007-02-21 2023-09-14 20:55:00             M          16       White
#
#       violation  search_conducted stop_outcome  is_arrested  \
# 86146  Speeding             False     Citation        False
# 86148  Speeding             False     Citation        False
# 86143  Speeding             False     Citation        False
#
#        drugs_related_stop  year
# 86146               False  2008
# 86148               False  2008
# 86143               False  2007

# %%
#print top 4 rows where driver_age is 21 and the driver gender is M
df.loc[(df.driver_age==21)&(df.driver_gender=='M')].head(4)
# Out:
#        stop_date           stop_time driver_gender  driver_age driver_race  \
# 86126 2006-10-11 2023-09-14 10:55:00             M          21       White
#
#               violation  search_conducted stop_outcome  is_arrested  \
# 86126  Moving violation             False     Citation        False
#
#        drugs_related_stop  year
# 86126               False  2006

# %%
#iloc
# Price the data at row 5 and column 6
df.iloc[5,6]
# Out:
# False

# %%
df.iloc[:5,:6]
# Out:
#    stop_date           stop_time driver_gender  driver_age driver_race  \
# 0 2013-09-08 2023-09-14 09:50:00             F         109       White
# 1 2006-09-06 2023-09-14 12:15:00             M         105       White
# 2 2014-02-14 2023-09-14 10:21:00             M         103       White
# 3 2008-02-04 2023-09-14 14:40:00             M         101       White
# 4 2008-02-15 2023-09-14 14:34:00             M         101       White
#
#           violation
# 0  Moving violation
# 1          Speeding
# 2  Moving violation
# 3          Speeding
# 4          Speeding

# %% [markdown]
# ###  Sorting “sort_index()” and “sort_values()”

# %%
# sort values
# extract driver age, driver_race, and violation
df.loc[:,['driver_age','driver_race','violation']].sort_values(by='driver_age')
# Out:
#        driver_age driver_race            violation
# 86153          10       White  Registration/plates
# 86152          12       White                Other
# 86150          14    Hispanic             Speeding
# 86151          14       White                Other
# 86149          15       White             Speeding
# ...           ...         ...                  ...
# 4             101       White             Speeding
# 3             101       White             Speeding
# 2             103       White     Moving violation
# 1             105       White             Speeding
# 0             109       White     Moving violation
#
# [86154 rows x 3 columns]

# %% [markdown]
# ### `Query` filter our data frame as per our conditions

# %%
# print top 10 rows where the drivers are between 31 to 50 years old 
df.query('driver_age>30 & driver_age<=50').head(10)
# Out:
#        stop_date           stop_time driver_gender  driver_age driver_race  \
# 29813 2005-09-28 2023-09-14 07:15:00             M          50       White
# 29814 2005-10-01 2023-09-14 19:25:00             M          50       White
# 29815 2005-10-04 2023-09-14 12:30:00             M          50       White
# 29816 2005-10-07 2023-09-14 00:50:00             M          50    Hispanic
# 29817 2005-10-07 2023-09-14 01:52:00             M          50       White
# 29818 2005-10-08 2023-09-14 00:20:00             F          50       White
# 29819 2005-10-08 2023-09-14 07:25:00             M          50       White
# 29820 2005-10-10 2023-09-14 12:30:00             M          50       White
# 29821 2005-10-10 2023-09-14 23:50:00             M          50       Black
# 29822 2005-10-12 2023-09-14 23:54:00             M          50       Black
#
#               violation  search_conducted   stop_outcome  is_arrested  \
# 29813          Speeding             False       Citation        False
# 29814          Speeding             False       Citation        False
# 29815          Speeding             False       Citation        False
# 29816  Moving violation             False  Arrest Driver         True
# 29817          Speeding             False       Citation        False
# 29818          Speeding             False       Citation        False
# 29819          Speeding             False       Citation        False
# 29820          Speeding             False       Citation        False
# 29821          Speeding             False       Citation        False
# 29822  Moving violation             False       Citation        False
#
#        drugs_related_stop  year
# 29813               False  2005
# 29814               False  2005
# 29815               False  2005
# 29816               False  2005
# 29817               False  2005
# 29818               False  2005
# 29819               False  2005
# 29820               False  2005
# 29821               False  2005
# 29822               False  2005

# %%
# print three different entries where driver is 18 years old and female
df.query('driver_age==18 & driver_gender=="M"').sample(3)
# Out:
#        stop_date           stop_time driver_gender  driver_age driver_race  \
# 86131 2007-06-24 2023-09-14 09:37:00             M          18    Hispanic
# 86132 2008-02-24 2023-09-14 22:51:00             M          18    Hispanic
# 86130 2005-10-17 2023-09-14 08:32:00             M          18       White
#
#               violation  search_conducted stop_outcome  is_arrested  \
# 86131          Speeding             False     Citation        False
# 86132         Equipment             False     Citation        False
# 86130  Moving violation             False     Citation        False
#
#        drugs_related_stop  year
# 86131               False  2007
# 86132               False  2008
# 86130               False  2005

# %%
#Find out top 3 entries where the driver age is 21, violation is "Speeding", driver is not arrested
df1=df.query('driver_age>=45 & violation=="Speeding" & is_arrested==False')

# %%
df1.head()
df1.shape
# Out:
# (22514, 11)

# %% [markdown]
# ## Save dataframe to CSV format

# %%
df1.to_csv('police_new.csv',index=False) #need extension

# %%
df_new=pd.read_csv('police_new.csv',index_col=[0])
df_new.sample(5)
# Out:
#                       stop_time driver_gender  driver_age driver_race  \
# stop_date
# 2009-02-08  2023-09-14 08:50:00             F          61       White
# 2009-02-16  2023-09-14 11:46:00             M          56    Hispanic
# 2008-09-06  2023-09-14 13:05:00             M          46       White
# 2009-01-16  2023-09-14 16:30:00             M          46       White
# 2006-07-14  2023-09-14 11:46:00             M          65       White
#
#            violation  search_conducted stop_outcome  is_arrested  \
# stop_date
# 2009-02-08  Speeding             False     Citation        False
# 2009-02-16  Speeding             False     Citation        False
# 2008-09-06  Speeding             False     Citation        False
# 2009-01-16  Speeding             False     Citation        False
# 2006-07-14  Speeding             False     Citation        False
#
#             drugs_related_stop  year
# stop_date
# 2009-02-08               False  2009
# 2009-02-16               False  2009
# 2008-09-06               False  2008
# 2009-01-16               False  2009
# 2006-07-14               False  2006

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22514 entries, 2006-09-06 to 2015-12-30
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_time           22514 non-null  object
#  1   driver_gender       22514 non-null  object
#  2   driver_age          22514 non-null  int64
#  3   driver_race         22514 non-null  object
#  4   violation           22514 non-null  object
#  5   search_conducted    22514 non-null  bool
#  6   stop_outcome        22514 non-null  object
#  7   is_arrested         22514 non-null  bool
#  8   drugs_related_stop  22514 non-null  bool
#  9   year                22514 non-null  int64
# dtypes: bool(3), int64(2), object(5)
# memory usage: 1.4+ MB
